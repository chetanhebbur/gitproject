# %%
print("Hello from Git!")
print("Pushing code from India!")
# Out:
# Hello from Git!
# Pushing code from India!

# %%
name = input("What is your name? ")
print(f"Hello, {name}! Welcome to Git programming.")
print("This is a simple Python script to demonstrate Git usage.")
print("You can modify this code and push it to your Git repository.")
print("Happy coding with Git!")
# Out:
# Hello, chethan! Welcome to Git programming.
# This is a simple Python script to demonstrate Git usage.
# You can modify this code and push it to your Git repository.
# Happy coding with Git!
